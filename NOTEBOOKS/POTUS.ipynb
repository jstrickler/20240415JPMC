# %% [markdown]
# # Working with presidents

# %%
import pandas as pd

# %%
df = pd.read_csv('../DATA/presidents.csv',names='term first_name last_name birthplace birth_state party'.split())
df
# Out:
#     term                first_name   last_name                  birthplace  \
# 0      1                    George  Washington         Westmoreland County
# 1      2                      John       Adams          Braintree, Norfolk
# 2      3                    Thomas   Jefferson           Albermarle County
# 3      4                     James     Madison                 Port Conway
# 4      5                     James      Monroe         Westmoreland County
# 5      6               John Quincy       Adams          Braintree, Norfolk
# 6      7                    Andrew     Jackson                      Waxhaw
# 7      8                    Martin   Van Buren                  Kinderhook
# 8      9             William Henry    Harrison                    Berkeley
# 9     10                      John       Tyler         Charles City County
# 10    11                James Knox        Polk          Mecklenburg County
# ...

# %%
df.value_counts('party')
# Out:
# party
# Republican                 20
# Democratic                 16
# Democratic - Republican     4
# Whig                        4
# Federalist                  1
# no party                    1
# Name: count, dtype: int64
